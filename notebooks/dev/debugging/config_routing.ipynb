# %%
import os
from resurfemg.data_connector.config import Config

# %%
# path = None
# path = '.\\dev\\debugging\\config_routing.ipynb'
# readable_path = path.replace(
#         os.sep if os.altsep is None else os.altsep, os.sep)
# print(readable_path)

# %%
config = Config(verbose=True, force=True)
# Out:
# ERROR:root:Required directory C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed2 does not exist
# Loaded config from:
#  C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\config.json
#
# The following name-path combinations are configured:
# -------------------------------------------------------------------------------
#   Name           	Path
# -------------------------------------------------------------------------------
#   root_data      	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed2
# -------------------------------------------------------------------------------
# * patient_data   	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed2\patient_data
# * simulated_data 	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed2\simulated_data
# * preprocessed_data	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed2\preprocessed_data
# * output_data    	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed2\output_data
#   test_data      	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\test_data
# -------------------------------------------------------------------------------
# * Path is relative to root_data
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 config = Config(verbose=True)
#
# File ~\Repos\ReSurfEMG\ReSurfEMG\resurfemg\data_connector\config.py:166, in Config.__init__(self, location, verbose, force)
#     164     print('The following name-path combinations are configured:')
#     165     self.print_config()
# --> 166 self.validate(_path)
#
# File ~\Repos\ReSurfEMG\ReSurfEMG\resurfemg\data_connector\config.py:345, in Config.validate(self, _path, force)
#     342     continue
#     343 logging.error('Required directory %s does not exist',
#     344               self._loaded[req_dir])
# --> 345 raise ValueError(
#     346     f'Required directory {req_dir} specified in the config '
#     347     + 'file does not exist. Create it yourself or re-run with '
#     348     + '`force=True` to create the root data directory at:\n '
#     349     + f'{self._loaded[req_dir]}\n'
#     350     + 'Alternatively, edit the config file at:\n '
#     351     + f'{_path}\n')
#
# ValueError: Required directory root_data specified in the config file does not exist. Create it yourself or re-run with `force=True` to create the root data directory at:
#  C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed2
# Alternatively, edit the config file at:
#  C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\config.json

# %%
config.get_directory('non_existing_key')
# Out:
# Directory `non_existing_key` not found in config.
# The following directories are configured:
# -------------------------------------------------------------------------------
#   Name           	Path
# -------------------------------------------------------------------------------
#   root_data      	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed
# -------------------------------------------------------------------------------
# * patient_data   	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed\patient_data
# * simulated_data 	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed\simulated_data
# * preprocessed_data	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed\preprocessed_data
# * output_data    	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\not_pushed\output_data
#   test_data      	C:\Users\WarnaarRSP\Repos\ReSurfEMG\ReSurfEMG\test_data
# -------------------------------------------------------------------------------
# * Path is relative to root_path
